# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

# %%
res = llm.invoke("who is pm of india?")
print(res.content)
# Out:
# The current Prime Minister of India is Narendra Modi. He has been in office since May 26, 2014, and is serving his second consecutive term as the Prime Minister of India.
